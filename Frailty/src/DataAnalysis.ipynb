# %%
import pandas as pd

# %%
data_frame = pd.read_csv('/Users/prasanna/Documents/GitHub/Principles-of-DataScience/Frailty/CleanData/Frailty.csv')

# %%
print(data_frame.to_string())
# Out:
#    Unnamed: 0.1  Unnamed: 0 Height Weight  Age Grip Strength Frailty
# 0             0           0  65.8    112   30            30       N
# 1             1           1  71.5    136   19            31       N
# 2             2           2  69.4    153   45            29       N
# 3             3           3  68.2    142   22            28       Y
# 4             4           4  67.8    144   29            24       Y
# 5             5           5  68.7    123   50            26       N
# 6             6           6  69.8    141   51            22       Y
# 7             7           7  70.1    136   23            20       Y
# 8             8           8  67.9    112   17            19       N
# 9             9           9  66.8    120   39            31       N

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   10 non-null     int64
#  1   Unnamed: 0     10 non-null     int64
#  2   Height         10 non-null     object
#  3   Weight         10 non-null     object
#  4   Age            10 non-null     object
#  5   Grip Strength  10 non-null     object
#  6   Frailty        10 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 692.0+ bytes

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import numpy as np

# %%
ax = data_frame.plot.scatter(x='Weight',y='Grip Strength')

# %%
fig = ax.get_figure()

# %%
fig.savefig("/Users/prasanna/Documents/GitHub/Principles-of-DataScience/Frailty/Results/GripStrength_weight-Relation.png")

# %%
ax = sns.histplot(data_frame['Grip Strength'], kde=False, color='green', bins=30)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig = ax.get_figure()

# %%
fig.savefig("/Users/prasanna/Documents/GitHub/Principles-of-DataScience/Frailty/Results/GripStrength_Distribution.png")
